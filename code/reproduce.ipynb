# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import generate_site_gmm, Trainer
from Original_EM import *

# %%
df_res, df_path = run_section5_simulation(
    n_list=(1000,),
    K_list=(10, 30),
    sigma2_list=(2.5, 5.0),
    a_list=(0.1, 0.3),
    n_rep=200,
    max_iter=50,
    seed=2026
)
# Out:
# [1/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=0
# [2/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=1
# [3/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=2
# [4/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=3
# [5/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=4
# [6/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=5
# [7/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=6
# [8/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=7
# [9/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=8
# [10/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=9
# [11/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=10
# [12/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=11
# [13/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=12
# [14/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=13
# [15/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=14
# [16/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=15
# [17/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=16
# [18/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=17
# [19/1600] n=1000, K=10, sigma2=2.5, a=0.1, rep=18
# ...

# %%
plot_basic(df_path, n=1000, K=10)
plot_bias_boxplot(df_res, n=1000)
plot_mse_boxplot(df_res, n=1000)
